# %% [markdown]
# ## Lesson 4

# %%
point = (10,20)

# %%
x,y = point
print x
# Out:
# 10

# %%
params = {"parameter1" : 1.0, "paramter2" : 2.0, "paramter3": 3.0}

# %%
print(type(params))
# Out:
# <type 'dict'>

# %%
print params["parameter1"]
# Out:
# 1.0

# %%
params["paramter1"]="A"

# %%
print params["paramter1"]
# Out:
# A

# %%
statement1 = True
statement2 = False

if statement1:
    print('Statement 1 is true')
elif statement2 == False:
    print('nothing')
else:
    print('Statement 2 is false')
# Out:
# Statement 1 is true

# %%
for key, value in params.items():
    print (key, "is " ,value)
# Out:
# ('parameter1', 'is ', 1.0)
# ('paramter3', 'is ', 3.0)
# ('paramter2', 'is ', 2.0)

# %%
for idx, x in enumerate(range(-3,3)):
    print (idx,x)
# Out:
# (0, -3)
# (1, -2)
# (2, -1)
# (3, 0)
# (4, 1)
# (5, 2)

# %%
def func0():
    print("test")

# %%
func0()
# Out:
# test

# %%
def func2(s):
    '''
    test func
    '''
    print('you entered '+s)
func2("hello")
# Out:
# you entered hello

# %%
help(func2)
# Out:
# Help on function func2 in module __main__:
#
# func2(s)
#     test func

# %%
class Point:
    '''
    Simple class for representing a point
    '''

    def __init__(self,x,y):
        '''
        Create a new point x,y
        '''
        self.x = x
        self.y = y
    
    def translate(self, dx, dy):
        '''
        translate the point by dx and dy in the x and y direction
        '''
        self.x += dx
        self.y += dy
    
    def __str__(self):
        return("Point at [%f,%f]" % (self.x,self.y))

# %%
p1 = Point(1,2)
print p1
# Out:
# Point at [1.000000,2.000000]

# %%
print(type(p1))
# Out:
# <type 'instance'>

# %%
p1.translate(0.25,1.5)

# %%
print p1
# Out:
# Point at [1.250000,3.500000]

# %%
# %matplotlib inline

# %%
# !which python
# Out:
# //anaconda/bin/python

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.arange(0,1,0.1)
y = x**2
plt.plot(x,y);

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
alpha = 0.7
phi_ext = 2 * np.pi * 0.5

def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2*np.cos(phi_p) * np.cos(phi_m) -alpha * np.cos(phi_ext - phi_p)

# %%
phi_m = np.linspace(0,2*np.pi, 100)
phi_p = np.linspace(0,2*np.pi, 100)
X,Y = np.meshgrid(phi_p, phi_m)
Z = flux_qubit_potential(X,Y).T

# %%
fig = plt.figure()

ax = fig.add_subplot(1, 1, 1, projection='3d')

p = ax.plot_wireframe(X,Y,Z, rstride=4, cstride= 4)

# %%
from ipywidgets import interact
def pltwxy(az, el):
    fig = plt.figure(figsize=(15,7))
    ax = fig.add_subplot(1,2,1, projection='3d')
    ax.plot_surface(X,Y,Z, rstride=4, cstride=4, alpha=0.25)
    ax.view_init(az, el)
    
interact(pltwxy, az=(0, 100,30), el=(0, 90, 5));
